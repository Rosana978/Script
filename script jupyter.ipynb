# %%
import xarray as xr
# Especifica el patrón de archivos .nc utilizando caracteres comodín (*)
archivos_nc_model = 'C:\\Users\\Rosana\\Desktop\\TFM\\dataset\\*.nc'
# Abre el archivo con xarray usando open_mfdataset
ds_model = xr.open_mfdataset(archivos_nc_model, engine='netcdf4', chunks=None)

# %%
#Abre dimensiones, coordenadas, variables, indices y atributos
ds_model
# Out:
# <xarray.Dataset>
# Dimensions:                       (time: 75, level: 137, flux_level: 138,
#                                    frequency: 2)
# Coordinates:
#   * time                          (time) datetime64[ns] 2019-01-02 ... 2019-0...
#   * level                         (level) int16 137 136 135 134 133 ... 4 3 2 1
#   * flux_level                    (flux_level) int16 138 137 136 135 ... 4 3 2 1
#   * frequency                     (frequency) float32 35.0 94.0
# Data variables: (12/59)
#     latitude                      (time) float32 37.15 37.15 ... 37.15 37.15
#     longitude                     (time) float32 356.4 356.4 ... 356.4 356.4
#     horizontal_resolution         (time) float32 9.0 9.0 9.0 9.0 ... 9.0 9.0 9.0
#     forecast_time                 (time) timedelta64[ns] dask.array<chunksize=(25,), meta=np.ndarray>
#     pressure                      (time, level) float32 dask.array<chunksize=(25, 137), meta=np.ndarray>
# ...
